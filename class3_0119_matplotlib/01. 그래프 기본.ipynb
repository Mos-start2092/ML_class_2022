# %% [markdown]
# ! pip install matplotlib

# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터를 시각화할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 그래프 기본

# %%
x=[1,2,3]
y=[2,4,8]

# %%
plt.plot(x,y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000002240E08E640>]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x,y)
plt.title('Line Graph')
plt.show()

# %%
plt.plot(x,y)
#plt.title('꺽은선 그래프')
plt.show()

# %%
import matplotlib
matplotlib.rcParams['font.family'] = "Malgun Gothic"

# 글자 크기
matplotlib.rcParams['font.size']=15

# %%
import matplotlib.font_manager as fm
#fm.fontManager.ttflist

# %%
#[f.name for f in  fm.fontManager.ttflist]

# %%
plt.plot(x,y)
plt.title('꺽은선 그래프')
plt.show()

# %%
plt.plot([-1,0,1],[-5,-1,2])
# Out:
# C:\Users\sungb\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\sungb\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 마이너스 출력 옵션

# %%
matplotlib.rcParams['axes.unicode_minus']=False

# %%
plt.plot([-1,0,1],[-5,-1,2])
